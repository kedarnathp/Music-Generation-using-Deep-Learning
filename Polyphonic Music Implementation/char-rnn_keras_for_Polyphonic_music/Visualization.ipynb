# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv('logs/training_log.csv')
df
# Out:
#     epoch      loss       acc
# 0       1  2.812543  0.225410
# 1       2  1.695670  0.529503
# 2       3  1.193229  0.658234
# 3       4  1.021466  0.695175
# 4       5  0.915027  0.718369
# 5       6  0.848333  0.733650
# 6       7  0.801100  0.745743
# 7       8  0.763011  0.754738
# 8       9  0.729129  0.762741
# 9      10  0.699289  0.773140
# 10     11  0.670570  0.782295
# 11     12  0.643534  0.790573
# 12     13  0.616790  0.798088
# 13     14  0.591912  0.806770
# 14     15  0.568585  0.814690
# 15     16  0.543880  0.823006
# 16     17  0.523847  0.828514
# 17     18  0.497694  0.838730
# 18     19  0.479574  0.844185
# 19     20  0.456488  0.851562
# 20     21  0.436871  0.857193
# 21     22  0.416956  0.864334
# 22     23  0.398345  0.870033
# 23     24  0.378149  0.876106
# 24     25  0.361798  0.882065
# 25     26  0.345011  0.887123
# 26     27  0.330554  0.891747
# 27     28  0.316122  0.896492
# 28     29  0.304115  0.900032
# 29     30  0.292684  0.903603
# ..    ...       ...       ...
# 70     71  0.107468  0.963997
# 71     72  0.104615  0.965103
# 72     73  0.101788  0.966202
# 73     74  0.101039  0.966026
# 74     75  0.099179  0.967064
# 75     76  0.100592  0.966141
# 76     77  0.101981  0.966194
# 77     78  0.096148  0.967903
# 78     79  0.097957  0.967354
# 79     80  0.094508  0.968353
# 80     81  0.093107  0.968971
# 81     82  0.094258  0.968880
# 82     83  0.093852  0.968704
# 83     84  0.092729  0.969345
# 84     85  0.091532  0.969864
# 85     86  0.092116  0.969757
# 86     87  0.089156  0.970482
# 87     88  0.088105  0.970161
# 88     89  0.087971  0.970345
# 89     90  0.088104  0.970665
# 90     91  0.090031  0.969749
# 91     92  0.089079  0.969849
# 92     93  0.087962  0.970757
# 93     94  0.087949  0.970642
# 94     95  0.086787  0.970985
# 95     96  0.084789  0.971626
# 96     97  0.084640  0.971786
# 97     98  0.082200  0.972366
# 98     99  0.082042  0.972473
# 99    100  0.080192  0.973183
#
# [100 rows x 3 columns]

# %%
sns.set()

# %%
plt.figure(figsize=(10, 8))
plt.plot(df['epoch'], df['loss'],c='green')
plt.title('Training Loss over Epochs')
plt.show()

# %%
plt.figure(figsize=(10, 8))
plt.plot(df['epoch'], df['acc'],c='g')
plt.title('Training Accuracy over Epochs')
plt.show()
